# %% [markdown]
# # This notebook is used for cleaning the data and creating two datasets that will later be used in fake and real news article classifier.

# %%
import pandas as pd
import numpy as np
import re
import string

# %%
fake_original = pd.read_csv("Raw_datasets/Fake.csv")
true_original = pd.read_csv("Raw_datasets/True.csv")
mixture = pd.read_csv("Raw_datasets/news_articles.csv")
fake = fake_original.copy()
true = true_original.copy()
mixture_clean = mixture.copy()

# %%
mixture_clean = mixture_clean.dropna()
mixture_clean = mixture_clean[['title','text', 'published', 'label', 'title_without_stopwords','text_without_stopwords']]

fake = fake.dropna()
true = true.dropna()

# %%
def wordCorrect(text):
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub("\\W", " ", text)
    text = re.sub("https?://\S+|www\. \S+", "", text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    
    return text

# %%
mixture_clean.rename(columns={"published":"date"}, inplace=True)
#YYYY-MM-DDThh:mm:ss.sTZD our current date format.

mixture_clean = mixture_clean[~mixture_clean.date.str.contains('http')]



mixture_clean['date'] = pd.to_datetime(mixture_clean['date'], utc=True)
mixture_clean.date = pd.to_datetime(mixture_clean.date).dt.date

# %%
fake = fake[fake.date.str.contains('20')]
true = true[true.date.str.contains('20')]

#in case some URL has 20 written inside of them.
fake = fake[~fake.date.str.contains('http')]
true = true[~true.date.str.contains('http')]

# %%
fake['date'] = pd.to_datetime(fake['date'])
true['date'] = pd.to_datetime(true['date'])
fake.drop(['subject'], axis=1, inplace=True)
true.drop(['subject'], axis=1, inplace=True)

# %%
mixture_clean['title'] = mixture_clean['title'].apply(wordCorrect)
mixture_clean['text'] = mixture_clean['text'].apply(wordCorrect)
mixture_clean['title_without_stopwords'] = mixture_clean['title_without_stopwords'].apply(wordCorrect)
mixture_clean['text_without_stopwords'] = mixture_clean['text_without_stopwords'].apply(wordCorrect)

fake['title'] = fake['title'].apply(wordCorrect)
true['title'] = true['title'].apply(wordCorrect)
true['text'] = true['text'].apply(wordCorrect)
fake['text'] = fake['text'].apply(wordCorrect)
# Out:
#                                                   title  \
# 0     muslims busted they stole millions in govt ben...
# 1     re why did attorney general loretta lynch plea...
# 2     breaking weiner cooperating with fbi on hillar...
# 3     pin drop speech by father of daughter kidnappe...
# 4     fantastic trumps  point plan to reform healthc...
# 5     hillary goes absolutely berserk on protester a...
# 6     breaking nypd ready to make arrests in weiner ...
# 7     wow whistleblower tells chilling story of mass...
# 8     breaking clinton clearedwas this a coordinated...
# 9     evil hillary supporters yell fck trumpburn tru...
# 10    yikes hillary goes off the railspulls a howard...
# 11    say goodbye these  hollywood celebs threatened...
# 12    not kidding colleges give students safe spaces...
# 13    boom math shows trump would have beaten obama ...
# 14    boom this is how president reagan handled prot...
# 15    trump supporter got nuts on msnbc reporter cov...
# 16    tomi lahren has special message for celebritie...
# 17    boycottcomedianrobert deniro wanted to punch t...
# 18    hes never sold an original painting until nowa...
# 19    sorry liberalsyou can stop with the petitionsh...
# 20    mark cuban in the event donald wins i have no ...
# 21    trump supporter whose brutal beating by black ...
# 22    wow white liberals suggest blacks are too stup...
# 23    lol british wife of lib actor who said there w...
# 24    epic tucker carlson demolishes nyc councilman ...
# 25    funny snls solution to democrat election denia...
# 26    donald trump calls meeting with pressdresses d...
# 27    oops crybaby hamilton stars who lectured pence...
# 28    white trumpbashing lib reprimanded on live cnn...
# 29          boom kellyanne conway shuts down cnns cuomo
# ...                                                 ...
# 2016  impeachmentera evidence against bill clinton s...
# 2017         un declares junk food a human rights issue
# 2018        yes creationists can be real scientists too
# 2019         un declares junk food a human rights issue
# 2020  impeachmentera evidence against bill clinton s...
# 2021   the man who spoke softly but carried a big stick
# 2022        yes creationists can be real scientists too
# 2023   the man who spoke softly but carried a big stick
# 2024    federal judge charges sheriff joe with contempt
# 2025    federal judge charges sheriff joe with contempt
# 2026         all about jesus shirt sparks school uproar
# 2027   loretta lynch takes on killer cops  except in dc
# 2028  will it be representative government or thugoc...
# 2029               of hillarys scandals the early years
# 2030                 why never trumpers must reconsider
# 2031        election crossroads socialism or capitalism
# 2032                         reasons ill vote for trump
# 2033   our new country women and minorities hit hardest
# 2034              trump vs clinton a risk vs a disaster
# 2035                    gingrich slutshames megyn kelly
# 2036  clinton transmitted classified info to her law...
# 2037                    youtube bans clintons black son
# 2038   loretta lynch takes on killer cops  except in dc
# 2039  will it be representative government or thugoc...
# 2040               of hillarys scandals the early years
# 2041                 why never trumpers must reconsider
# 2042        election crossroads socialism or capitalism
# 2043                         reasons ill vote for trump
# 2044   our new country women and minorities hit hardest
# 2045              trump vs clinton a risk vs a disaster
#
#                                                    text        date label  \
# 0     print they should pay all the back all the mon...  2016-10-26  Real
# 1     why did attorney general loretta lynch plead t...  2016-10-29  Real
# 2     red state   fox news sunday reported this morn...  2016-10-30  Real
# 3     email kayla mueller was a prisoner and torture...  2016-11-01  Real
# 4     email healthcare reform to make america great ...  2016-11-01  Real
# 5     print hillary goes absolutely berserk she expl...  2016-11-02  Real
# 6     breaking nypd ready to make arrests in weiner ...  2016-11-04  Real
# 7     breaking nypd ready to make arrests in weiner ...  2016-11-04  Real
# 8     limbaugh said that the revelations in the wiki...  2016-11-06  Real
# 9     email  these people are sick and evil they wil...  2016-11-07  Real
# 10    who comedian  where would she move spain i did...  2016-11-07  Real
# 11    students expressed their fear over a trump pre...  2016-11-09  Real
# 12    email for republican politicians like ohio gov...  2016-11-10  Real
# 13    copyright   percentfedupcom in association wit...  2016-11-10  Real
# 14    go to article a trump supporter wearing a trum...  2016-11-11  Real
# 15    copyright   percentfedupcom in association wit...  2016-11-12  Real
# 16    go to article donald trump was willing to give...  2016-11-10  Real
# 17    john mcnaughton is a special american painter ...  2016-11-12  Real
# 18    go to article dear abby i supported a woman i ...  2016-11-13  Real
# 19    mark cuban has made no secret of his dislike f...  2016-11-13  Real
# 20    david wilcox a  year old chicago man who was b...  2016-11-10  Real
# 21    go to article filmmaker ami horowitz takes to ...  2016-11-14  Real
# 22    go to article  political activist and hillary ...  2016-11-15  Real
# 23    go to article rafael salamancas interview on t...  2016-11-20  Real
# 24    go to article in the bubble life continues for...  2016-11-20  Real
# 25    go to article  they had to know they had it co...  2016-11-21  Real
# 26    donald trump skips media delivers transition u...  2016-11-22  Real
# 27    go to article the left is shameful in their la...  2016-11-22  Real
# 28    boom kellyanne conway shuts down cnns cuomo ba...  2016-11-22  Real
# 29    sharia in america how minneapolis muslims are ...  2016-11-23  Real
# ...                                                 ...         ...   ...
# 2016  bellwether trump kippas outselling hillary yar...  2016-10-26  Real
# 2017  show biz business and breakthroughs exclusive ...  2016-10-26  Real
# 2018  print  when judith gait met father x it was a ...  2016-10-26  Real
# 2019  wars and rumors of wars nato calls for more tr...  2016-10-26  Real
# 2020  exrep if trump loses im grabbing my musket pre...  2016-10-26  Real
# 2021  rand paul returns  to us treasury i promised k...  2016-10-26  Real
# 2022  wars and rumors of wars nato calls for more tr...  2016-10-26  Real
# 2023  exrep if trump loses im grabbing my musket pre...  2016-10-26  Real
# 2024  rand paul returns  to us treasury i promised k...  2016-10-26  Real
# 2025  show biz business and breakthroughs exclusive ...  2016-10-26  Real
# 2026  print  when judith gait met father x it was a ...  2016-10-26  Real
# 2027  donations world wildlife falls by  in  years c...  2016-10-26  Real
# 2028  boycott targets trump family on retail front p...  2016-10-26  Real
# 2029  obamacare tax penalty ill take it millions say...  2016-10-26  Real
# 2030  yearold hebrew mention of jerusalem found rare...  2016-10-26  Real
# 2031  donations world wildlife falls by  in  years c...  2016-10-26  Real
# 2032  dems sue gop over trumps rigged complaints cla...  2016-10-26  Real
# 2033  yearold hebrew mention of jerusalem found rare...  2016-10-26  Real
# 2034  boycott targets trump family on retail front p...  2016-10-26  Real
# 2035  obamacare tax penalty ill take it millions say...  2016-10-26  Real
# 2036  dems sue gop over trumps rigged complaints cla...  2016-10-26  Real
# 2037  hillary emails whitelisted for obamas blackber...  2016-10-27  Real
# 2038  support for assaultweapon ban hits record low ...  2016-10-27  Real
# 2039  pope god promised the land to people of israel...  2016-10-27  Real
# 2040  christs burial place exposed for st time in ce...  2016-10-27  Real
# 2041  prof canoes reek of genocide white privilege c...  2016-10-27  Real
# 2042  teens walk free after gangrape conviction judg...  2016-10-27  Real
# 2043  school named for munichmassacre mastermind ter...  2016-10-27  Real
# 2044  wars and rumors of wars russia unveils satan  ...  2016-10-27  Real
# 2045  check out hillarythemed haunted house anticlin...  2016-10-27  Real
#
#                                 title_without_stopwords  \
# 0           muslims busted stole millions govt benefits
# 1            attorney general loretta lynch plead fifth
# 2     breaking weiner cooperating fbi hillary email ...
# 3     pin drop speech father daughter kidnapped kill...
# 4     fantastic trumps point plan reform healthcare ...
# 5     hillary goes absolutely berserk protester rall...
# 6     breaking nypd ready make arrests weiner casehi...
# 7     wow whistleblower tells chilling story massive...
# 8     breaking clinton clearedwas coordinated last m...
# 9     evil hillary supporters yell fck trumpburn tru...
# 10      yikes hillary goes railspulls howard dean video
# 11    say goodbye hollywood celebs threatened leave ...
# 12    kidding colleges give students safe spaces cry...
# 13    boom math shows trump would beaten obama romne...
# 14    boom president reagan handled protesters negot...
# 15    trump supporter got nuts msnbc reporter coveri...
# 16    tomi lahren special message celebrities said t...
# 17    boycottcomedianrobert deniro wanted punch trum...
# 18    hes never sold original painting nowand ones g...
# 19    sorry liberalsyou stop petitionshillary win po...
# 20    mark cuban event donald wins doubt market tank...
# 21    trump supporter whose brutal beating black mob...
# 22    wow white liberals suggest blacks stupid get i...
# 23    lol british wife lib actor said never presiden...
# 24    epic tucker carlson demolishes nyc councilman ...
# 25    funny snls solution democrat election denial s...
# 26    donald trump calls meeting pressdresses real f...
# 27    oops crybaby hamilton stars lectured pence hav...
# 28    white trumpbashing lib reprimanded live cnn in...
# 29               boom kellyanne conway shuts cnns cuomo
# ...                                                 ...
# 2016  impeachmentera evidence bill clinton still sealed
# 2017                 man spoke softly carried big stick
# 2018                   yes creationists real scientists
# 2019                 man spoke softly carried big stick
# 2020         federal judge charges sheriff joe contempt
# 2021         federal judge charges sheriff joe contempt
# 2022                   jesus shirt sparks school uproar
# 2023          loretta lynch takes killer cops except dc
# 2024               representative government thugocracy
# 2025                      hillarys scandals early years
# 2026                     never trumpers must reconsider
# 2027           election crossroads socialism capitalism
# 2028                             reasons ill vote trump
# 2029           new country women minorities hit hardest
# 2030                  trump vs clinton risk vs disaster
# 2031                    gingrich slutshames megyn kelly
# 2032        clinton transmitted classified info lawyers
# 2033                    youtube bans clintons black son
# 2034          loretta lynch takes killer cops except dc
# 2035               representative government thugocracy
# 2036                      hillarys scandals early years
# 2037                     never trumpers must reconsider
# 2038           election crossroads socialism capitalism
# 2039                             reasons ill vote trump
# 2040           new country women minorities hit hardest
# 2041                  trump vs clinton risk vs disaster
# 2042                    gingrich slutshames megyn kelly
# 2043                    youtube bans clintons black son
# 2044             wikileaks bombshells hillary need know
# 2045                                     fascinated sex
#
#                                  text_without_stopwords
# 0     print pay back money plus interest entire fami...
# 1     attorney general loretta lynch plead fifth bar...
# 2     red state fox news sunday reported morning ant...
# 3     email kayla mueller prisoner tortured isis cha...
# 4     email healthcare reform make america great sin...
# 5     print hillary goes absolutely berserk explodes...
# 6     breaking nypd ready make arrests weiner casehi...
# 7     breaking nypd ready make arrests weiner casehi...
# 8     limbaugh said revelations wikileaks material s...
# 9     email people sick evil stop nothing get way la...
# 10    comedian would move spain buy house another co...
# 11    students expressed fear trump presidency messa...
# 12    email republican politicians like ohio governo...
# 13    copyright percentfedupcom association liberty ...
# 14    go article trump supporter wearing trumppence ...
# 15    copyright percentfedupcom association liberty ...
# 16    go article donald trump willing give fulfillin...
# 17    john mcnaughton special american painter subje...
# 18    go article dear abby supported woman knew hist...
# 19    mark cuban made secret dislike trump love croo...
# 20    david wilcox year old chicago man brutally bea...
# 21    go article filmmaker ami horowitz takes street...
# 22    go article political activist hillary supporte...
# 23    go article rafael salamancas interview tucker ...
# 24    go article bubble life continues progressive a...
# 25    go article know coming donald trump scolded me...
# 26    donald trump skips media delivers transition u...
# 27    go article left shameful latest effort create ...
# 28    boom kellyanne conway shuts cnns cuomo barracu...
# 29    sharia america minneapolis muslims still recru...
# ...                                                 ...
# 2016  exrep trump loses im grabbing musket previousl...
# 2017  rand paul returns us treasury promised kentuck...
# 2018  wars rumors wars nato calls troops faceoff put...
# 2019  exrep trump loses im grabbing musket previousl...
# 2020  rand paul returns us treasury promised kentuck...
# 2021  show biz business breakthroughs exclusive vane...
# 2022  print judith gait met father x lopsided grief ...
# 2023  donations world wildlife falls years critic th...
# 2024  boycott targets trump family retail front part...
# 2025  obamacare tax penalty ill take millions say la...
# 2026  yearold hebrew mention jerusalem found rare pa...
# 2027  donations world wildlife falls years critic th...
# 2028  dems sue gop trumps rigged complaints claim ar...
# 2029  yearold hebrew mention jerusalem found rare pa...
# 2030  boycott targets trump family retail front part...
# 2031  obamacare tax penalty ill take millions say la...
# 2032  dems sue gop trumps rigged complaints claim ar...
# 2033  hillary emails whitelisted obamas blackberry p...
# 2034  support assaultweapon ban hits record low even...
# 2035  pope god promised land people israel statement...
# 2036  christs burial place exposed st time centuries...
# 2037  prof canoes reek genocide white privilege craf...
# 2038  teens walk free gangrape conviction judge said...
# 2039  school named munichmassacre mastermind terrori...
# 2040  wars rumors wars russia unveils satan missile ...
# 2041  check hillarythemed haunted house anticlinton ...
# 2042  good samaritan wearing indian headdress disarm...
# 2043  skype sex scam fortune built shame moroccan bo...
# 2044  posted eddie skyhigh potency may scare away cr...
# 2045  billion even known keeping supposedly deleted ...
#
# [2043 rows x 6 columns]

# %%
is_real = mixture_clean['label'] == 'Real'
mix_true_stop = mixture_clean[is_real]
mix_true_stop = mix_true_stop.drop(['title', 'label', 'text'], axis=1)

mix_true = mixture_clean[is_real]
mix_true = mix_true.drop(['title_without_stopwords', 'text_without_stopwords', 'label'], axis=1)

# %%
mix_fake_stop = mixture_clean[~is_real]
mix_fake_stop = mix_fake_stop.drop(['title', 'label', 'text'], axis=1)

mix_fake = mixture_clean[~is_real]
mix_fake = mix_fake.drop(['title_without_stopwords', 'text_without_stopwords', 'label'], axis=1)

# %%
#Correct order of columns should be [title, text, date]
mix_true_stop = mix_true_stop[['title_without_stopwords', 'text_without_stopwords', 'date']]
mix_fake_stop = mix_fake_stop[['title_without_stopwords', 'text_without_stopwords', 'date']]

mix_true = mix_true[['title','text','date']]
mix_fake = mix_fake[['title','text','date']]

mix_fake_stop.reset_index(drop=True, inplace=True)
mix_true_stop.reset_index(drop=True, inplace=True)
mix_true.reset_index(drop=True, inplace=True)
mix_fake.reset_index(drop=True, inplace=True)
fake.reset_index(drop=True, inplace=True)
true.reset_index(drop=True, inplace=True)

# %%
mix_true.to_csv('Datasets/mix_true.csv', header =True)
mix_fake.to_csv('Datasets/mix_fake.csv', header =True)

fake.to_csv('Datasets/fake.csv', header =True)
true.to_csv('Datasets/true.csv', header =True)

mix_true_stop.to_csv('Datasets/mix_true_with_stop.csv', header =True)
mix_fake_stop.to_csv('Datasets/mix_fake_with_stop.csv', header =True)

# %%
fake['legit'] = 0
true['legit'] = 1

# %%
fakeTrue = pd.concat([fake,true])
fakeTrue.reset_index(drop=True, inplace=True)

# %%
fakeTrue.to_csv('Datasets/fakeTrue.csv', index=True, header=True)
